# %% [markdown]
# ### Dependencies

# %%
from apify_client import ApifyClient
from dotenv import load_dotenv
import pandas as pd
import os

# %%
DATA_PATH = "../data"

# %% [markdown]
# ### Initialization

# %%
# Load environment variables
load_dotenv()

# Fetching values
API_TOKEN = os.getenv("API_TOKEN")

# Initialize the ApifyClient with Apify API token
client = ApifyClient(API_TOKEN)

# Prepare the Actor input for the Instagram Scraper
# This example scrapes posts from a specific profile
run_input = {
    "directUrls": ["https://www.instagram.com/haleemasyed__/"],  # URL of the Instagram profile
    "resultsType": "posts",  # Specify to scrape posts
    "resultsLimit": 50,      # Limit the number of results
}

# %%
# Run the Instagram Scraper Actor and wait for it to finish
# The 'apify/instagram-scraper' is a pre-built Actor available on Apify Store
print("Running Instagram Scraper Actor...")
run = client.actor("apify/instagram-scraper").call(run_input=run_input)
print(f"Actor run finished. Check logs: https://console.apify.com/actors/apify/instagram-scraper/runs/{run['id']}")

# Fetch scraped data into a list
data = []
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    data.append(item)

# Convert to pandas DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv(f"{DATA_PATH}/instagram_scraped_data.csv", index=False, encoding="utf-8")

print("\nData saved successfully to instagram_scraped_data.csv")

print(f"\nData also available in dataset: https://console.apify.com/storage/datasets/{run['defaultDatasetId']}")
# Out:
# Running Instagram Scraper Actor...
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> Status: RUNNING, Message:
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:34.412Z ACTOR: Pulling Docker image of build ZP2X6OZpcYd4letWr from registry.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:34.414Z ACTOR: Creating Docker container.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:34.460Z ACTOR: Starting Docker container.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:36.342Z INFO  System info {"apifyVersion":"3.4.4","apifyClientVersion":"2.12.2","crawleeVersion":"3.13.2","osType":"Linux","nodeVersion":"v20.19.5"}
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:36.483Z INFO  Results Limit [object Object], ACTOR_MAX_PAID_DATASET_ITEMS 1801
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:36.486Z INFO  pushDataMaxAware 1801
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:36.769Z INFO  [Status message]: Starting the scraper with 1 direct URL(s)
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> Status: RUNNING, Message: Starting the crawler.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:36.955Z INFO  CheerioCrawler: Starting the crawler.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:40.010Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request blocked, retrying it again with different session
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> Status: RUNNING, Message: Crawled 1/2 pages, 0 failed requests, desired concurrency 52.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:40.012Z  {"id":"vyULRA9HyHBT3wI","url":"https://i.instagram.com/api/v1/users/web_profile_info/?username=haleemasyed__","retryCount":1}
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:51.385Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request blocked, retrying it again with different session
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> Status: RUNNING, Message: Crawled 25/41 pages, 0 failed requests, desired concurrency 52.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:51.387Z     at handlePostDetails (file:///usr/src/app/dist/src/routes/post-details.js:115:15) {"id":"7TYd4plyAc51R4X","url":"https://www.instagram.com/api/graphql","retryCount":1}
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:58.441Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request blocked, retrying it again with different session
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:48:58.443Z     at handlePostDetails (file:///usr/src/app/dist/src/routes/post-details.js:115:15) {"id":"E6ysIHztSERrLhI","url":"https://www.instagram.com/api/graphql","retryCount":1}
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:01.700Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request blocked, retrying it again with different session
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:01.702Z     at handlePostDetails (file:///usr/src/app/dist/src/routes/post-details.js:115:15) {"id":"i0fqfBGTyFTzinC","url":"https://www.instagram.com/api/graphql","retryCount":1}
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:02.499Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Request blocked, retrying it again with different session
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:02.501Z     at handlePostDetails (file:///usr/src/app/dist/src/routes/post-details.js:115:15) {"id":"xOaRK43QoZ4Cp6F","url":"https://www.instagram.com/api/graphql","retryCount":1}
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:04.969Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. The proxy server rejected the request with status code 590 (UPSTREAM503)
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> Status: RUNNING, Message: Crawled 51/56 pages, 0 failed requests, desired concurrency 52.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> Status: RUNNING, Message: Crawled 53/56 pages, 0 failed requests, desired concurrency 52.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:04.971Z  {"id":"jziZ2v9yMBc2N0K","url":"https://www.instagram.com/api/graphql","retryCount":1}
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> Status: RUNNING, Message: Crawled 55/56 pages, 0 failed requests, desired concurrency 52.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:20.164Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. request timed out after 30 seconds. {"id":"mMewNPH9oRmQRtb","url":"https://www.instagram.com/api/graphql","retryCount":1}
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:29.803Z INFO  CheerioCrawler: All requests from the queue have been processed, the crawler will shut down.
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:29.893Z INFO  CheerioCrawler: Final request statistics: {"requestsFinished":56,"requestsFailed":0,"retryHistogram":[49,7],"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":3439,"requestsFinishedPerMinute":63,"requestsFailedPerMinute":0,"requestTotalDurationMillis":192609,"requestsTotal":56,"crawlerRuntimeMillis":53073}
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:29.895Z INFO  CheerioCrawler: Finished! Total 56 requests: 56 succeeded, 0 failed. {"terminal":true}
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> 2025-09-18T08:49:29.905Z INFO  [Status message]: Scraper finished
# [apify.instagram-scraper runId:smLYkbQiqg54mV8Yz] -> Status: SUCCEEDED, Message: Scraper finished
# Actor run finished. Check logs: https://console.apify.com/actors/apify/instagram-scraper/runs/smLYkbQiqg54mV8Yz
#
# Data saved successfully to instagram_scraped_data.csv
#
# Data also available in dataset: https://console.apify.com/storage/datasets/QFKhSkHw7jH3JGtUm
